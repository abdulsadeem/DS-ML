# %% [markdown]
# # Introduction to Machine Learning
#
# Machine Learning is a technique that allows computers to learn from data instead of being programmed with fixed rules. In traditional programming, we write the logic step by step and give the computer data to get results. But in Machine Learning, we provide data along with the correct outputs, and the computer finds patterns and learns the rules by itself. This helps machines make predictions or decisions automatically based on past examples.
